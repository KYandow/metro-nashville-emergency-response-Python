# %% [markdown]
# Import Data

# %%
import pandas as pd
import folium 
from folium.plugins import MarkerCluster
from folium.features import DivIcon
import geopandas as gdp
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Point

from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
from folium.plugins import *
from folium.features import *
import sys
sys.path.insert(0,'folium')
##import seaborn as sns

derecho911_df = pd.read_csv("..\data\911_Phone Calls_Derecho_050320 050420.csv")
tornado911_df = pd.read_csv("..\data\911_Phone_Calls_Tornado_030320.csv")

derecho_incidents_df = pd.read_csv("..\data\Computer Aided Dispatch Data_Derecho Incidents 050320_050420.csv", skiprows=3)
tornado_incidents_df = pd.read_csv("..\data\Computer Aided Dispatch Data_Tornado Incidents 030320.csv", skiprows=3)

##print(derecho911_df.head(100))
print(tornado911_df)
# Out:
#     Seizure DateTime CallTypeId  ALI Latitude  ALI Longitude  \
# 0      3/3/2020 0:34  911 Calls     36.072708     -86.665779
# 1      3/3/2020 0:36  911 Calls     36.159634     -86.841904
# 2      3/3/2020 0:36  911 Calls     36.264153     -86.708862
# 3      3/3/2020 0:36  911 Calls           NaN            NaN
# 4      3/3/2020 0:36  911 Calls     36.233467     -86.721077
# ..               ...        ...           ...            ...
# 470    3/3/2020 4:54  911 Calls     36.142552     -86.635330
# 471    3/3/2020 4:54  911 Calls     36.189415     -86.813557
# 472    3/3/2020 4:55  911 Calls     36.223534     -86.757874
# 473    3/3/2020 4:56  911 Calls     36.168398     -86.783774
# 474    3/3/2020 4:58  911 Calls     36.276566     -86.799417
#
#                     Cell Tower Address
# 0           620 Richards RD - N Sector
# 1               4507D KENTUCKY AV - SE
# 2             329 THELMA ST - S Sector
# 3                       526 FOUNDRY DR
# 4                 5007B RUSKIN AVE - N
# ..                                 ...
# 470                    WIRELESS CALLER
# 471                    WIRELESS CALLER
# 472                    WIRELESS CALLER
# 473  600 DR MARTIN L KING JR BLVD - NE
# 474             4884 LICKTON PIKE - SE
#
# [475 rows x 5 columns]

# %% [markdown]
# 4a. Locations less impacted or not impacted based on call volume( or lack thereof)

# %%
#print(derecho911_df.head(5))
print(tornado911_df.head(5))
#Derecho911_df.groupby('a').count()
derecho911_df['ALI Latitude'] = derecho911_df['ALI Latitude'].fillna(0)
derecho911_df['ALI Longitude'] = derecho911_df['ALI Longitude'].fillna(0)



##Turn NaNs into zeroes
derecho911_df['LatLong'] = derecho911_df.apply(lambda row: [row['ALI Latitude'], row['ALI Longitude']], axis=1)



##Make a latLong column which contains an array which is the form required for map markers
map = folium.Map(location=[36.247802, -86.716847], zoom_start=12)

##This is an arbitrary location within Nashville to start; this could be more centered
m = folium.TileLayer('stamentoner').add_to(map)
for location in derecho911_df['LatLong']:
    folium.Marker(location=location).add_to(map)
map


#neighborhoods = gdp.read_file('..\data\zipcodes.geojson')
#print(neighborhoods.crs)
#neighborhoods.head()
# Out:
#   Seizure DateTime CallTypeId  ALI Latitude  ALI Longitude  \
# 0    3/3/2020 0:34  911 Calls     36.072708     -86.665779
# 1    3/3/2020 0:36  911 Calls     36.159634     -86.841904
# 2    3/3/2020 0:36  911 Calls     36.264153     -86.708862
# 3    3/3/2020 0:36  911 Calls           NaN            NaN
# 4    3/3/2020 0:36  911 Calls     36.233467     -86.721077
#
#            Cell Tower Address
# 0  620 Richards RD - N Sector
# 1      4507D KENTUCKY AV - SE
# 2    329 THELMA ST - S Sector
# 3              526 FOUNDRY DR
# 4        5007B RUSKIN AVE - N
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
zipcodes = gdp.read_file('..\data\zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# zipcodes.geometry.to_crs('EPSG:4326')
# print(zipcodes.crs)
zipcodes.plot();
# Out:
# epsg:4326

# %%
leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 2}

zipcodes.plot(column = 'zip', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')
plt.show()

# %%
derecho911_df = pd.read_csv("..\data\911_Phone Calls_Derecho_050320 050420.csv")
tornado911_df = pd.read_csv("..\data\911_Phone_Calls_Tornado_030320.csv")
#print(derecho911_df.shape)
#derecho911_df.head(3)
#print(tornado911_df.head(5))
#tornado911_df.head(3)


#print(derecho911_df)
derecho911_df['Seizure DateTime'].replace('', np.nan, inplace=True)
derecho911_df['CallTypeId'].replace('', np.nan, inplace=True)
derecho911_df['ALI Latitude'].replace('', np.nan, inplace=True)
derecho911_df['ALI Longitude'].replace('', np.nan, inplace=True)
derecho911_df['Cell Tower Address'].replace('', np.nan, inplace=True)

##derecho911_df = derecho911_df[derecho911_df['ALI Latitude'].notna()]
derecho911_df = derecho911_df.dropna()
#print(derecho911_df)
derecho911_df = derecho911_df.rename(columns={"ALI Latitude": "lat", "ALI Longitude": "lng"}, errors="raise")



#print(tornado911_df)
tornado911_df['Seizure DateTime'].replace('', np.nan, inplace=True)
tornado911_df['CallTypeId'].replace('', np.nan, inplace=True)
tornado911_df['ALI Latitude'].replace('', np.nan, inplace=True)
tornado911_df['ALI Longitude'].replace('', np.nan, inplace=True)
tornado911_df['Cell Tower Address'].replace('', np.nan, inplace=True)

##derecho911_df = derecho911_df[derecho911_df['ALI Latitude'].notna()]
tornado911_df = tornado911_df.dropna()
#print(derecho911_df)
tornado911_df = tornado911_df.rename(columns={"ALI Latitude": "lat", "ALI Longitude": "lng"}, errors="raise")

# %%
derecho911_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1483 entries, 0 to 1547
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Seizure DateTime    1483 non-null   object
#  1   CallTypeId          1483 non-null   object
#  2   lat                 1483 non-null   float64
#  3   lng                 1483 non-null   float64
#  4   Cell Tower Address  1483 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 69.5+ KB

# %%
derecho911_df['geometry'] = derecho911_df.apply(lambda x: Point((float(x.lng), 
                                                         float(x.lat))), 
                                        axis=1)

derecho911_df.head(3)


tornado911_df['geometry'] = tornado911_df.apply(lambda x: Point((float(x.lng), 
                                                         float(x.lat))), 
                                        axis=1)

tornado911_df.head(3)
# Out:
#   Seizure DateTime CallTypeId        lat        lng  \
# 0    3/3/2020 0:34  911 Calls  36.072708 -86.665779
# 1    3/3/2020 0:36  911 Calls  36.159634 -86.841904
# 2    3/3/2020 0:36  911 Calls  36.264153 -86.708862
#
#            Cell Tower Address                      geometry
# 0  620 Richards RD - N Sector  POINT (-86.665779 36.072708)
# 1      4507D KENTUCKY AV - SE  POINT (-86.841904 36.159634)
# 2    329 THELMA ST - S Sector  POINT (-86.708862 36.264153)

# %%
zipcodes.loc[0, 'geometry']

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
derecho911_geo = gdp.GeoDataFrame(derecho911_df, 
                           crs = zipcodes.crs, 
                           geometry = derecho911_df['geometry'])


tornado911_geo = gdp.GeoDataFrame(tornado911_df, 
                           crs = zipcodes.crs, 
                           geometry = tornado911_df['geometry'])

# %%
#type(derecho911_geo)
#type(tornado911_geo)
print(derecho911_geo)
# Out:
#      Seizure DateTime CallTypeId        lat        lng  \
# 0      5/3/2020 16:30  911 Calls  36.247802 -86.716847
# 1      5/3/2020 16:30  911 Calls  36.143108 -86.800621
# 2      5/3/2020 16:30  911 Calls  36.100516 -87.056329
# 3      5/3/2020 16:30  911 Calls  36.130021 -86.927819
# 4      5/3/2020 16:31  911 Calls  36.142380 -86.881882
# ...               ...        ...        ...        ...
# 1543    5/4/2020 0:16  911 Calls  36.067911 -86.622970
# 1544    5/4/2020 0:18  911 Calls  36.131694 -86.770535
# 1545    5/4/2020 0:22  911 Calls  36.042237 -86.743455
# 1546    5/4/2020 0:25  911 Calls  36.077664 -86.655607
# 1547    5/4/2020 0:29  911 Calls  36.024706 -86.743562
#
#                        Cell Tower Address                    geometry
# 0                         WIRELESS CALLER  POINT (-86.71685 36.24780)
# 1                     1161 21ST AV S - SE  POINT (-86.80062 36.14311)
# 2                   8013 C MCCRORY LN - N  POINT (-87.05633 36.10052)
# 3                      5758 RIVER RD - SW  POINT (-86.92782 36.13002)
# 4                    3744B ANNEX AVE - SE  POINT (-86.88188 36.14238)
# ...                                   ...                         ...
# 1543                      WIRELESS CALLER  POINT (-86.62297 36.06791)
# 1544         1823-C 12TH AV - SECTOR SE S  POINT (-86.77053 36.13169)
# 1545     5244-C EDMONSON PIKE - SECTOR SE  POINT (-86.74346 36.04224)
# 1546  2747-B MURFREESBORO PKE - SECTOR NW  POINT (-86.65561 36.07766)
# 1547               302 SUMMIT VIEW DR - E  POINT (-86.74356 36.02471)
#
# [1483 rows x 6 columns]

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

print(zipcodes)
# Out:
#       zip         po_name                                           geometry
# 0   37115         MADISON  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1   37216       NASHVILLE  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2   37204       NASHVILLE  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3   37027       BRENTWOOD  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4   37064        FRANKLIN  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...
# 5   37143          PEGRAM  MULTIPOLYGON (((-87.03553 36.08659, -87.03556 ...
# 6   37080         JOELTON  MULTIPOLYGON (((-86.86263 36.37811, -86.86264 ...
# 7   37221       NASHVILLE  MULTIPOLYGON (((-86.97084 36.11644, -86.97084 ...
# 8   37072  GOODLETTSVILLE  MULTIPOLYGON (((-86.75361 36.40428, -86.75354 ...
# 9   37212       NASHVILLE  MULTIPOLYGON (((-86.80790 36.14643, -86.80605 ...
# 10  37135     NOLENSVILLE  MULTIPOLYGON (((-86.67188 35.98955, -86.67189 ...
# 11  37027       BRENTWOOD  MULTIPOLYGON (((-86.72012 36.00886, -86.72012 ...
# 12  37209       NASHVILLE  MULTIPOLYGON (((-86.97543 36.20877, -86.97221 ...
# 13  37206       NASHVILLE  MULTIPOLYGON (((-86.75348 36.16274, -86.75383 ...
# 14  37027       BRENTWOOD  MULTIPOLYGON (((-86.68705 36.01059, -86.68695 ...
# 15  37072  GOODLETTSVILLE  MULTIPOLYGON (((-86.85290 36.38014, -86.85327 ...
# 16  37027       BRENTWOOD  MULTIPOLYGON (((-86.72541 36.00934, -86.72540 ...
# 17  37217       NASHVILLE  MULTIPOLYGON (((-86.67355 36.12729, -86.66687 ...
# 18  37189    WHITES CREEK  MULTIPOLYGON (((-86.84400 36.32689, -86.83591 ...
# 19  37207       NASHVILLE  MULTIPOLYGON (((-86.78596 36.29097, -86.78595 ...
# 20  37080         JOELTON  MULTIPOLYGON (((-86.90742 36.39053, -86.90725 ...
# 21  37027       BRENTWOOD  MULTIPOLYGON (((-86.68475 35.99279, -86.68488 ...
# 22  37138     OLD HICKORY  MULTIPOLYGON (((-86.61068 36.24413, -86.61039 ...
# 23  37143          PEGRAM  MULTIPOLYGON (((-86.98862 36.17033, -86.98767 ...
# 24  37219       NASHVILLE  MULTIPOLYGON (((-86.78609 36.17465, -86.78585 ...
# 25  37027       BRENTWOOD  MULTIPOLYGON (((-86.68367 35.99140, -86.68419 ...
# 26  37072  GOODLETTSVILLE  MULTIPOLYGON (((-86.76191 36.39867, -86.76200 ...
# 27  37218       NASHVILLE  MULTIPOLYGON (((-86.88231 36.26248, -86.88270 ...
# 28  37076       HERMITAGE  MULTIPOLYGON (((-86.52159 36.13816, -86.52174 ...
# 29  37027       BRENTWOOD  MULTIPOLYGON (((-86.67793 35.98782, -86.67941 ...
# 30  37232       NASHVILLE  MULTIPOLYGON (((-86.79984 36.14507, -86.80037 ...
# 31  37213       NASHVILLE  MULTIPOLYGON (((-86.77787 36.17706, -86.77810 ...
# 32  37205       NASHVILLE  MULTIPOLYGON (((-86.81907 36.13351, -86.81688 ...
# 33  37015    ASHLAND CITY  MULTIPOLYGON (((-86.88867 36.28013, -86.88867 ...
# 34  37143          PEGRAM  MULTIPOLYGON (((-86.99041 36.13785, -86.99045 ...
# 35  37203       NASHVILLE  MULTIPOLYGON (((-86.78734 36.16688, -86.78711 ...
# 36  37201       NASHVILLE  MULTIPOLYGON (((-86.77973 36.17460, -86.77823 ...
# 37  37214       NASHVILLE  MULTIPOLYGON (((-86.65585 36.11824, -86.66410 ...
# 38  37015    ASHLAND CITY  MULTIPOLYGON (((-86.92773 36.28074, -86.92769 ...
# 39  37240       NASHVILLE  MULTIPOLYGON (((-86.80304 36.14960, -86.80233 ...
# 40  37208       NASHVILLE  MULTIPOLYGON (((-86.81084 36.19254, -86.81083 ...
# 41  37122    MOUNT JULIET  MULTIPOLYGON (((-86.57430 36.19041, -86.57397 ...
# 42  37207       NASHVILLE  MULTIPOLYGON (((-86.75459 36.29021, -86.75465 ...
# 43  37027       BRENTWOOD  MULTIPOLYGON (((-86.68006 35.99132, -86.67966 ...
# 44  37215       NASHVILLE  MULTIPOLYGON (((-86.81428 36.12618, -86.81425 ...
# 45  37228       NASHVILLE  MULTIPOLYGON (((-86.78387 36.19400, -86.78318 ...
# 46  37076       HERMITAGE  MULTIPOLYGON (((-86.57085 36.13534, -86.57099 ...
# 47  37210       NASHVILLE  MULTIPOLYGON (((-86.70788 36.16764, -86.70778 ...
# 48  37143          PEGRAM  MULTIPOLYGON (((-87.03682 36.09556, -87.03611 ...
# 49  37211       NASHVILLE  MULTIPOLYGON (((-86.75696 36.13189, -86.75693 ...
# 50  37086       LA VERGNE  MULTIPOLYGON (((-86.58870 36.02671, -86.58836 ...
# 51  37013         ANTIOCH  MULTIPOLYGON (((-86.66517 36.09108, -86.66526 ...
# 52  37027       BRENTWOOD  MULTIPOLYGON (((-86.73108 36.00985, -86.73153 ...
# 53  37220       NASHVILLE  MULTIPOLYGON (((-86.76043 36.08004, -86.76043 ...
# 54  37122    MOUNT JULIET  MULTIPOLYGON (((-86.56426 36.16238, -86.56337 ...
# 55  37152        RIDGETOP  MULTIPOLYGON (((-86.75775 36.39996, -86.75773 ...

# %%
derecho911_calls_by_zip = gdp.sjoin(derecho911_geo, zipcodes, op = 'within')
tornado911_calls_by_zip = gdp.sjoin(tornado911_geo, zipcodes, op = 'within')

# %%
derecho911_calls_by_zip.head()
tornado911_calls_by_zip.head()
# Out:
#     Seizure DateTime CallTypeId        lat        lng  \
# 0      3/3/2020 0:34  911 Calls  36.072708 -86.665779
# 10     3/3/2020 0:38  911 Calls  36.052055 -86.648331
# 64     3/3/2020 0:53  911 Calls  36.050048 -86.650629
# 194    3/3/2020 1:29  911 Calls  36.068298 -86.681550
# 234    3/3/2020 1:40  911 Calls  36.058578 -86.699745
#
#                 Cell Tower Address                    geometry  index_right  \
# 0       620 Richards RD - N Sector  POINT (-86.66578 36.07271)           51
# 10       745 BELL RD - OMNI Sector  POINT (-86.64833 36.05205)           51
# 64             5646 AMALIE DR - SE  POINT (-86.65063 36.05005)           51
# 194  3930 APACHE TRAIL - SE SECTOR  POINT (-86.68155 36.06830)           51
# 234           5067 COLEMONT DR - N  POINT (-86.69974 36.05858)           51
#
#        zip  po_name
# 0    37013  ANTIOCH
# 10   37013  ANTIOCH
# 64   37013  ANTIOCH
# 194  37013  ANTIOCH
# 234  37013  ANTIOCH

# %%
derecho911_calls_by_zip['zip'].value_counts()
# Out:
# 37211    194
# 37013    191
# 37076    123
# 37205    100
# 37214     89
# 37217     73
# 37215     71
# 37209     68
# 37204     58
# 37207     55
# 37115     52
# 37210     51
# 37221     43
# 37220     39
# 37212     38
# 37203     33
# 37208     29
# 37206     27
# 37027     20
# 37216     20
# 37138     18
# 37218     10
# 37189      6
# 37080      4
# 37072      3
# 37232      3
# 37219      3
# 37213      2
# 37201      1
# 37122      1
# Name: zip, dtype: int64

# %%
tornado911_calls_by_zip['zip'].value_counts()
# Out:
# 37206    90
# 37208    80
# 37076    56
# 37214    32
# 37207    30
# 37209    24
# 37013    17
# 37203    14
# 37201    12
# 37115    12
# 37219     9
# 37210     8
# 37189     7
# 37217     7
# 37213     6
# 37211     5
# 37215     4
# 37072     3
# 37221     3
# 37216     3
# 37138     2
# 37212     2
# 37218     2
# 37205     2
# 37232     1
# 37080     1
# 37228     1
# 37204     1
# Name: zip, dtype: int64

# %%
# Set zipcode type to string (folium)
derecho911_calls_by_zip['zipcode'] = derecho911_calls_by_zip['zip'].astype('str')
derecho911_calls_by_zip['po_name'] = derecho911_calls_by_zip['po_name'].astype('str')
#print(derecho911_calls_by_zip)
# get the mean value across all data points
#zipcode_data = derecho911_calls_by_zip.groupby('zip').aggregate(np.mean)
zipcode_data = derecho911_calls_by_zip.groupby(['zip','po_name']).aggregate(np.mean)

zipcode_data.reset_index(inplace = True)

derecho911_calls_by_zip['count'] = 1
#temp = derecho911_calls_by_zip.groupby('zip').sum()
temp = derecho911_calls_by_zip.groupby(['zip','po_name']).sum()
temp.reset_index(inplace = True)
temp = temp[['zip', 'po_name','count']]
zipcode_data = pd.merge(zipcode_data, temp, on='zip')
derecho911_calls_by_zip.head(100)
# Out:
#     Seizure DateTime CallTypeId        lat        lng  \
# 0     5/3/2020 16:30  911 Calls  36.247802 -86.716847
# 68    5/3/2020 16:44  911 Calls  36.265547 -86.736116
# 78    5/3/2020 16:46  911 Calls  36.250710 -86.689766
# 79    5/3/2020 16:46  911 Calls  36.259485 -86.678717
# 100   5/3/2020 16:51  911 Calls  36.253467 -86.730366
# ..               ...        ...        ...        ...
# 769   5/3/2020 18:59  911 Calls  36.149162 -86.858833
# 771   5/3/2020 18:59  911 Calls  36.153463 -86.852653
# 786   5/3/2020 19:03  911 Calls  36.148517 -86.832654
# 810   5/3/2020 19:07  911 Calls  36.149225 -86.837590
# 812   5/3/2020 19:07  911 Calls  36.096439 -86.940844
#
#                   Cell Tower Address                    geometry  index_right  \
# 0                    WIRELESS CALLER  POINT (-86.71685 36.24780)            0
# 68         524 BOYDS HILLTOP DR - SW  POINT (-86.73612 36.26555)            0
# 78       607E LARKIN SPRINGS RD - SW  POINT (-86.68977 36.25071)            0
# 79       96 D VANDIVER DR - SECTOR S  POINT (-86.67872 36.25948)            0
# 100  619 DUE WEST AVE. W - NE SECTOR  POINT (-86.73037 36.25347)            0
# ..                               ...                         ...          ...
# 769  5619 CHARLOTTE PIKE - NE Sector  POINT (-86.85883 36.14916)           12
# 771                  WIRELESS CALLER  POINT (-86.85265 36.15346)           12
# 786                  WIRELESS CALLER  POINT (-86.83265 36.14852)           12
# 810                  WIRELESS CALLER  POINT (-86.83759 36.14923)           12
# 812         301 FOREST VALLEY DR - N  POINT (-86.94084 36.09644)           12
#
#        zip    po_name zipcode  count
# 0    37115    MADISON   37115      1
# 68   37115    MADISON   37115      1
# 78   37115    MADISON   37115      1
# 79   37115    MADISON   37115      1
# 100  37115    MADISON   37115      1
# ..     ...        ...     ...    ...
# 769  37209  NASHVILLE   37209      1
# 771  37209  NASHVILLE   37209      1
# 786  37209  NASHVILLE   37209      1
# 810  37209  NASHVILLE   37209      1
# 812  37209  NASHVILLE   37209      1
#
# [100 rows x 11 columns]

# %%
# Set zipcode type to string (folium)
tornado911_calls_by_zip['zipcode'] = tornado911_calls_by_zip['zip'].astype('str')
tornado911_calls_by_zip['po_name'] = tornado911_calls_by_zip['po_name'].astype('str')

# get the mean value across all data points
#zipcode_data_torn = tornado911_calls_by_zip.groupby('zip').aggregate(np.mean)
zipcode_data_torn = tornado911_calls_by_zip.groupby(['zip','po_name']).aggregate(np.mean)

zipcode_data_torn.reset_index(inplace = True)

tornado911_calls_by_zip['count'] = 1
#temp2 = tornado911_calls_by_zip.groupby('zip').sum()
temp2 = tornado911_calls_by_zip.groupby(['zip','po_name']).sum()
temp2.reset_index(inplace = True)
#temp2 = temp2[['zip', 'count']]
temp2 = temp2[['zip', 'po_name','count']]
zipcode_data_torn = pd.merge(zipcode_data_torn, temp2, on='zip')

#zipcode_data_torn['zip'].value_counts()

#zipcode_data_torn.head(100)
#print(zipcode_data_torn.sort_values(by=['zip'])
      
#mean = zipcode_data_torn["count_y"].mean()
#print(mean) -- 47.5

#zipcode_data_torn.count_y.quantile(0.25) # 25th percentile -- 2

#zipcode_data_torn.count_y.quantile(0.9) # 90th percentile -- 39.2
# Out:
# 39.20000000000002

# %%
zipcode_data['LatLong'] =  derecho911_df.apply(lambda row: [row['lat'], row['lng']], axis=1)
#zipcode_data.head(1000)

#print(zipcode_data['zip'])
#print(zipcode_data)

zipcode_data_torn['LatLong']=  tornado911_df.apply(lambda row: [row['lat'], row['lng']], axis=1)
zipcode_data_torn.head(100)

#print(zipcode_data_torn['zip'])
#print(zipcode_data_torn.head(5))
# Out:
#       zip       po_name_x        lat        lng  index_right  count_x  \
# 0   37013         ANTIOCH  36.052745 -86.667629           51        1
# 1   37072  GOODLETTSVILLE  36.310173 -86.711669            8        1
# 2   37076       HERMITAGE  36.183408 -86.604801           46        1
# 3   37080         JOELTON  36.322603 -86.867416           20        1
# 4   37115         MADISON  36.253868 -86.707988            0        1
# 5   37138     OLD HICKORY  36.233002 -86.615748           22        1
# 6   37189    WHITES CREEK  36.269705 -86.800453           18        1
# 7   37201       NASHVILLE  36.170921 -86.780266           36        1
# 8   37203       NASHVILLE  36.151157 -86.784851           35        1
# 9   37204       NASHVILLE  36.103905 -86.797806            2        1
# 10  37205       NASHVILLE  36.095759 -86.879573           32        1
# 11  37206       NASHVILLE  36.177118 -86.747062           13        1
# 12  37207       NASHVILLE  36.213185 -86.770817           42        1
# 13  37208       NASHVILLE  36.173628 -86.801240           40        1
# 14  37209       NASHVILLE  36.159178 -86.880093           12        1
# 15  37210       NASHVILLE  36.153389 -86.756405           47        1
# 16  37211       NASHVILLE  36.066367 -86.726744           49        1
# 17  37212       NASHVILLE  36.137146 -86.811065            9        1
# 18  37213       NASHVILLE  36.175819 -86.774143           31        1
# 19  37214       NASHVILLE  36.173595 -86.671208           37        1
# 20  37215       NASHVILLE  36.114261 -86.810151           44        1
# 21  37216       NASHVILLE  36.214728 -86.721183            1        1
# 22  37217       NASHVILLE  36.125855 -86.683263           17        1
# 23  37218       NASHVILLE  36.198974 -86.852075           27        1
# 24  37219       NASHVILLE  36.167699 -86.781707           24        1
# 25  37221       NASHVILLE  36.074141 -86.934528            7        1
# 26  37228       NASHVILLE  36.189438 -86.799713           45        1
# 27  37232       NASHVILLE  36.143108 -86.800621           30        1
#
#          po_name_y  count_y                                   LatLong
# 0          ANTIOCH       17                   [36.072708, -86.665779]
# 1   GOODLETTSVILLE        3          [36.159634000000004, -86.841904]
# 2        HERMITAGE       56                   [36.264153, -86.708862]
# 3          JOELTON        1                                       NaN
# 4          MADISON       12           [36.233467, -86.72107700000001]
# 5      OLD HICKORY        2           [36.149032, -86.79574699999999]
# 6     WHITES CREEK        7  [36.175810999999996, -86.89565400000001]
# 7        NASHVILLE       12             [36.1805, -86.88368100000001]
# 8        NASHVILLE       14                    [36.07098, -86.939964]
# 9        NASHVILLE        1           [36.163237, -86.77965400000001]
# 10       NASHVILLE        2          [36.052054999999996, -86.648331]
# 11       NASHVILLE       90                   [36.173183, -86.797335]
# 12       NASHVILLE       30                   [36.154944, -86.763432]
# 13       NASHVILLE       80           [36.169964, -86.85996999999999]
# 14       NASHVILLE       24                   [36.079605, -86.933418]
# 15       NASHVILLE        8           [36.103905, -86.79780600000001]
# 16       NASHVILLE        5           [36.120558, -86.80448100000001]
# 17       NASHVILLE        2           [36.169964, -86.85996999999999]
# 18       NASHVILLE        6          [36.183353000000004, -86.771561]
# 19       NASHVILLE       32          [36.175360999999995, -86.782658]
# 20       NASHVILLE        4           [36.166263, -86.85385500000001]
# 21       NASHVILLE        3                   [36.170395, -86.801689]
# 22       NASHVILLE        7                   [36.220014, -86.806433]
# 23       NASHVILLE        2           [36.177227, -86.87874599999999]
# 24       NASHVILLE        9                    [36.167431, -86.79686]
# 25       NASHVILLE        3           [36.169964, -86.85996999999999]
# 26       NASHVILLE        1                   [36.170395, -86.801689]
# 27       NASHVILLE        1                   [36.174191, -86.805983]

# %%
zipcode_data['count'] = zipcode_data['count'].astype(str)
zipcode_data['countInt'] = zipcode_data['count'].astype(np.int64)
#zipcode_data['po_name'] = zipcode_data['po_name'].astype(str)

zipcode_data_torn['count'] = zipcode_data_torn['count_y'].astype(str)
zipcode_data_torn['countInt'] = zipcode_data_torn['count_y'].astype(np.int64)
#zipcode_data['po_name'] = zipcode_data['po_name'].astype(str)



#community_df = pd.read_csv("..\data\Communities.csv")
#community_df.head(10)
#zipcode_data_torn.head(10)

# %% [raw]
# Derecho 911 Calls -  Map of locations least impacted, most impacted by the storms.

# %%
print(zipcode_data.head(100))
# Out:
#       zip       po_name_x        lat        lng  index_right       po_name_y  \
# 0   37013         ANTIOCH  36.049779 -86.650140        51.00         ANTIOCH
# 1   37027       BRENTWOOD  36.035693 -86.774822         3.55       BRENTWOOD
# 2   37072  GOODLETTSVILLE  36.307028 -86.725223         8.00  GOODLETTSVILLE
# 3   37076       HERMITAGE  36.187858 -86.605639        46.00       HERMITAGE
# 4   37080         JOELTON  36.343481 -86.884313        20.00         JOELTON
# 5   37115         MADISON  36.257933 -86.703841         0.00         MADISON
# 6   37122    MOUNT JULIET  36.154386 -86.570678        54.00    MOUNT JULIET
# 7   37138     OLD HICKORY  36.230566 -86.613884        22.00     OLD HICKORY
# 8   37189    WHITES CREEK  36.270880 -86.818937        18.00    WHITES CREEK
# 9   37201       NASHVILLE  36.174341 -86.783195        36.00       NASHVILLE
# 10  37203       NASHVILLE  36.146181 -86.793278        35.00       NASHVILLE
# 11  37204       NASHVILLE  36.111160 -86.781767         2.00       NASHVILLE
# 12  37205       NASHVILLE  36.118327 -86.860570        32.00       NASHVILLE
# 13  37206       NASHVILLE  36.178809 -86.745087        13.00       NASHVILLE
# 14  37207       NASHVILLE  36.217860 -86.770456        42.00       NASHVILLE
# 15  37208       NASHVILLE  36.175763 -86.807954        40.00       NASHVILLE
# 16  37209       NASHVILLE  36.139594 -86.876998        12.00       NASHVILLE
# 17  37210       NASHVILLE  36.138970 -86.735390        47.00       NASHVILLE
# 18  37211       NASHVILLE  36.068636 -86.725336        49.00       NASHVILLE
# 19  37212       NASHVILLE  36.129678 -86.800853         9.00       NASHVILLE
# 20  37213       NASHVILLE  36.168109 -86.769268        31.00       NASHVILLE
# 21  37214       NASHVILLE  36.165395 -86.669648        37.00       NASHVILLE
# 22  37215       NASHVILLE  36.100137 -86.823504        44.00       NASHVILLE
# 23  37216       NASHVILLE  36.217309 -86.727662         1.00       NASHVILLE
# 24  37217       NASHVILLE  36.108906 -86.670832        17.00       NASHVILLE
# 25  37218       NASHVILLE  36.191483 -86.835894        27.00       NASHVILLE
# 26  37219       NASHVILLE  36.166438 -86.781886        24.00       NASHVILLE
# 27  37220       NASHVILLE  36.068039 -86.771802        53.00       NASHVILLE
# 28  37221       NASHVILLE  36.064351 -86.966282         7.00       NASHVILLE
# 29  37232       NASHVILLE  36.143108 -86.800621        30.00       NASHVILLE
#
#    count                                   LatLong  countInt
# 0    191                   [36.247802, -86.716847]       191
# 1     20  [36.143108000000005, -86.80062099999999]        20
# 2      3                   [36.100516, -87.056329]         3
# 3    123                   [36.130021, -86.927819]       123
# 4      4  [36.142379999999996, -86.88188199999999]         4
# 5     52          [36.136683000000005, -86.861322]        52
# 6      1                   [36.047151, -86.962538]         1
# 7     18  [36.041453999999995, -86.66590699999999]        18
# 8      6           [36.093789, -86.83930600000001]         6
# 9      1                   [36.030716, -86.981613]         1
# 10    33                   [36.111588, -86.888101]        33
# 11    58                   [36.173944, -86.759934]        58
# 12   100           [36.113273, -86.84248199999999]       100
# 13    27           [36.097105, -86.83883399999999]        27
# 14    55                   [36.122221, -86.812119]        55
# 15    29           [36.150309, -86.85185899999999]        29
# 16    68           [36.152959, -86.62777700000001]        68
# 17    51                     [36.111052, -86.8663]        51
# 18   194           [36.144463, -86.86700400000001]       194
# 19    38                   [36.038418, -86.821239]        38
# 20     2                   [36.137391, -86.824951]         2
# 21    89                   [36.100613, -86.804609]        89
# 22    71                    [36.246193, -86.83847]        71
# 23    20                   [36.095486, -86.827377]        20
# 24    73                   [36.126984, -86.804886]        73
# 25    10                     [36.095486, -86.8274]        10
# 26     3                   [36.025114, -86.961551]         3
# 27    39                     [36.1309, -86.859734]        39
# 28    43           [36.074219, -86.72532700000001]        43
# 29     3                   [36.012314, -87.024445]         3

# %%
import branca

##Make a latLong column which contains an array which is the form required for map markers
map = folium.Map(location=[36.247802, -86.716847], zoom_start=11)


import branca.colormap as cm

#colormap = cm.LinearColormap(colors=['blue','red'], index=[0,200],vmin=0,vmax=200)
#colormap.caption = 'Number of calls per zip code location'
#colormap.add_to(map)

##This is an arbitrary location within Nashville to start; this could be more centered
m = folium.TileLayer('Stamen Toner').add_to(map)
#for location in zipcode_data['LatLong']:
      #folium.Marker(location=location, popup=zipcode_data.iloc[i]['zip']).add_to(map)
for i in range(0,len(zipcode_data)):
    if zipcode_data.iloc[i]['countInt'] <7:
        folium.Circle([zipcode_data.iloc[i]['lat'], 
                   zipcode_data.iloc[i]['lng']], 
                   #popup=zipcode_data.iloc[i]['zip'],
                  #popup='<strong>Location:\n' + zipcode_data.iloc[i]['po_name_x'] + '\n' + 'Zip Code:\n' + zipcode_data.iloc[i]['zip'] +'</strong>', 
                    popup = folium.Popup('<strong>Location:\n' + ' ' +  zipcode_data.iloc[i]['po_name_x'] + '&nbsp;&nbsp;&nbsp;' + 'Zip Code: ' + zipcode_data.iloc[i]['zip'] +'</strong>', max_width=300,min_width=300),
                      tooltip='<strong>Number of Calls: ' + zipcode_data.iloc[i]['count'] +'</strong>', 
                   #radius=  1000 ,
                   radius=float(zipcode_data.iloc[i]['countInt']) *200,

                   #label=float(zipcode_data.iloc[i]['count']), 
                  color='purple',
                  fill=True,
                  fill_color='purple' ,   
                    fill_opacity = 0.1
                 ).add_to(map)        

          
    elif zipcode_data.iloc[i]['countInt'] >= 102:
        folium.Circle([zipcode_data.iloc[i]['lat'], 
                   zipcode_data.iloc[i]['lng']], 
                   #popup=zipcode_data.iloc[i]['zip'],
                   #popup='<strong>Location:\n' + zipcode_data.iloc[i]['po_name_x'] + '\n' + 'Zip Code:\n' + zipcode_data.iloc[i]['zip'] +'</strong>', 
                    popup = folium.Popup('<strong>Location:\n' + ' ' + zipcode_data.iloc[i]['po_name_x'] + '&nbsp;&nbsp;&nbsp;' +  'Zip Code: ' + zipcode_data.iloc[i]['zip'] +'</strong>', max_width=300,min_width=300),
                   tooltip='<strong>Number of Calls :' + zipcode_data.iloc[i]['count'] +'</strong>', 
                   radius=float(zipcode_data.iloc[i]['countInt'])*20,
       
                   #label=float(zipcode_data.iloc[i]['count']),  
                  color='black',
                  fill=True,
                  fill_color='black',  
                    fill_opacity = 0.1
                     ).add_to(map)        
        


map.save("Derecho 911 Calls Map.html")
map

# %%
zipcode_data_torn.head(100)
# Out:
#       zip       po_name_x        lat        lng  index_right  count_x  \
# 0   37013         ANTIOCH  36.052745 -86.667629           51        1
# 1   37072  GOODLETTSVILLE  36.310173 -86.711669            8        1
# 2   37076       HERMITAGE  36.183408 -86.604801           46        1
# 3   37080         JOELTON  36.322603 -86.867416           20        1
# 4   37115         MADISON  36.253868 -86.707988            0        1
# 5   37138     OLD HICKORY  36.233002 -86.615748           22        1
# 6   37189    WHITES CREEK  36.269705 -86.800453           18        1
# 7   37201       NASHVILLE  36.170921 -86.780266           36        1
# 8   37203       NASHVILLE  36.151157 -86.784851           35        1
# 9   37204       NASHVILLE  36.103905 -86.797806            2        1
# 10  37205       NASHVILLE  36.095759 -86.879573           32        1
# 11  37206       NASHVILLE  36.177118 -86.747062           13        1
# 12  37207       NASHVILLE  36.213185 -86.770817           42        1
# 13  37208       NASHVILLE  36.173628 -86.801240           40        1
# 14  37209       NASHVILLE  36.159178 -86.880093           12        1
# 15  37210       NASHVILLE  36.153389 -86.756405           47        1
# 16  37211       NASHVILLE  36.066367 -86.726744           49        1
# 17  37212       NASHVILLE  36.137146 -86.811065            9        1
# 18  37213       NASHVILLE  36.175819 -86.774143           31        1
# 19  37214       NASHVILLE  36.173595 -86.671208           37        1
# 20  37215       NASHVILLE  36.114261 -86.810151           44        1
# 21  37216       NASHVILLE  36.214728 -86.721183            1        1
# 22  37217       NASHVILLE  36.125855 -86.683263           17        1
# 23  37218       NASHVILLE  36.198974 -86.852075           27        1
# 24  37219       NASHVILLE  36.167699 -86.781707           24        1
# 25  37221       NASHVILLE  36.074141 -86.934528            7        1
# 26  37228       NASHVILLE  36.189438 -86.799713           45        1
# 27  37232       NASHVILLE  36.143108 -86.800621           30        1
#
#          po_name_y  count_y                                   LatLong count  \
# 0          ANTIOCH       17                   [36.072708, -86.665779]    17
# 1   GOODLETTSVILLE        3          [36.159634000000004, -86.841904]     3
# 2        HERMITAGE       56                   [36.264153, -86.708862]    56
# 3          JOELTON        1                                       NaN     1
# 4          MADISON       12           [36.233467, -86.72107700000001]    12
# 5      OLD HICKORY        2           [36.149032, -86.79574699999999]     2
# 6     WHITES CREEK        7  [36.175810999999996, -86.89565400000001]     7
# 7        NASHVILLE       12             [36.1805, -86.88368100000001]    12
# 8        NASHVILLE       14                    [36.07098, -86.939964]    14
# 9        NASHVILLE        1           [36.163237, -86.77965400000001]     1
# 10       NASHVILLE        2          [36.052054999999996, -86.648331]     2
# 11       NASHVILLE       90                   [36.173183, -86.797335]    90
# 12       NASHVILLE       30                   [36.154944, -86.763432]    30
# 13       NASHVILLE       80           [36.169964, -86.85996999999999]    80
# 14       NASHVILLE       24                   [36.079605, -86.933418]    24
# 15       NASHVILLE        8           [36.103905, -86.79780600000001]     8
# 16       NASHVILLE        5           [36.120558, -86.80448100000001]     5
# 17       NASHVILLE        2           [36.169964, -86.85996999999999]     2
# 18       NASHVILLE        6          [36.183353000000004, -86.771561]     6
# 19       NASHVILLE       32          [36.175360999999995, -86.782658]    32
# 20       NASHVILLE        4           [36.166263, -86.85385500000001]     4
# 21       NASHVILLE        3                   [36.170395, -86.801689]     3
# 22       NASHVILLE        7                   [36.220014, -86.806433]     7
# 23       NASHVILLE        2           [36.177227, -86.87874599999999]     2
# 24       NASHVILLE        9                    [36.167431, -86.79686]     9
# 25       NASHVILLE        3           [36.169964, -86.85996999999999]     3
# 26       NASHVILLE        1                   [36.170395, -86.801689]     1
# 27       NASHVILLE        1                   [36.174191, -86.805983]     1
#
#     countInt
# 0         17
# 1          3
# 2         56
# 3          1
# 4         12
# 5          2
# 6          7
# 7         12
# 8         14
# 9          1
# 10         2
# 11        90
# 12        30
# 13        80
# 14        24
# 15         8
# 16         5
# 17         2
# 18         6
# 19        32
# 20         4
# 21         3
# 22         7
# 23         2
# 24         9
# 25         3
# 26         1
# 27         1

# %% [markdown]
# Tornado 911 Calls - Map of communities least affected, most affected by the storms

# %%
##Make a latLong column which contains an array which is the form required for map markers

map = folium.Map(location=[36.247802, -86.716847], zoom_start=11)


import branca.colormap as cm
#colormap = cm.LinearColormap(colors=['orange','red'], index=[0,200],vmin=0,vmax=200,)
#colormap.caption = 'Number of calls per zip code location'
#colormap.add_to(map)

##This is an arbitrary location within Nashville to start; this could be more centered
m = folium.TileLayer('Stamen Toner').add_to(map)
#for location in zipcode_data['LatLong']:
      #folium.Marker(location=location, popup=zipcode_data.iloc[i]['zip']).add_to(map)
for i in range(0,len(zipcode_data_torn)):
    if zipcode_data_torn.iloc[i]['countInt'] <3:
       folium.Circle([zipcode_data_torn.iloc[i]['lat'], 
                    zipcode_data_torn.iloc[i]['lng']],                    
                    popup = folium.Popup('<strong>Location:\n' + zipcode_data_torn.iloc[i]['po_name_x'] + '&nbsp;&nbsp;&nbsp;' + 'Zip Code: '+ zipcode_data.iloc[i]['zip'] +'</strong>', height=600, max_width=300,min_width=300),
                    tooltip='<strong>Number of Calls: ' + zipcode_data_torn.iloc[i]['count'] +'</strong>',                    
                    radius=float(zipcode_data_torn.iloc[i]['countInt']) * 200,                 
                    fill=True,                  
                    color='blue',
                    fill_color='blue',                   
                    fill_opacity = 0.2

                 ).add_to(map)        

          
    elif zipcode_data_torn.iloc[i]['countInt'] >39:        
        folium.Circle([zipcode_data_torn.iloc[i]['lat'],      
                   zipcode_data_torn.iloc[i]['lng']],  
                   popup = folium.Popup('<strong>Location:\n' +  zipcode_data_torn.iloc[i]['po_name_x']  + '&nbsp;&nbsp;&nbsp;' + 'Zip Code: ' + zipcode_data.iloc[i]['zip'] +'</strong>', height=600, max_width=300,min_width=300),
                   tooltip='<strong>Number of Calls: ' + zipcode_data_torn.iloc[i]['count'] +'</strong>',  
                   radius=float(zipcode_data_torn.iloc[i]['countInt']) * 20,                 
                   fill=False,
                   color='purple',
                   fill_color='purple', 
                   fill_opacity = 0.2
                     ).add_to(map)        
        
        
 
map.save("Tornado 911 Calls Map.html")
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
zipcode_data_torn['po_zip'] = zipcode_data_torn['po_name_x'].astype(str) + ' - ' + zipcode_data_torn['zip'].astype(str)
#zipcode_data_torn.head(10)
zipcode_data_torn_bar = zipcode_data_torn[(zipcode_data_torn.countInt < 3) | (zipcode_data_torn.countInt > 39)]

#zipcode_data_torn_bar.head(100)
# Out:
# <AxesSubplot:ylabel='po_zip'>

# %%
x = zipcode_data_torn_bar.sort_values(by='countInt',ascending=True)
ax = x.plot(kind='barh', figsize=(8, 10), x='po_zip', y='countInt',color='#eb4034', zorder=2, width=0.85)

totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.6, i.get_y()+.38, \
            #str(round((i.get_width()/total)*100, 2))+'%', 
             str(round((i.get_width()))),
            fontsize=15,
color='dimgrey')

 # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
 ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("Total Number of Calls", labelpad=20, weight='bold', size=16)

# Set y-axis label
ax.set_ylabel("Location", labelpad=20, weight='bold', size=16)

ax.get_legend().remove()
#ax.legend(loc='lower center', ncol=2, fancybox=True, borderpad=1, frameon=True,  title='Total Calls')
 
ax.set_title("Tornado Calls - Most Impacted, Least Impacted Areas", weight='bold', size=20)
# Out:
# Text(0.5, 1.0, 'Tornado Calls - Most Impacted, Least Impacted Areas')

# %%
zipcode_data['po_zip'] = zipcode_data['po_name_x'].astype(str) + ' - ' + zipcode_data['zip'].astype(str)
#colors = {'>100':'red','<100':'blue'}

#zipcode_data['color'] =  zipcode_data['countInt'].apply(lambda x: colors[x])
#zipcode_data['color'] = zipcode_data.loc[zipcode_data['countInt'] > 100, 'color'] = 'Red'

zipcode_data_derecho_bar = zipcode_data[(zipcode_data.countInt < 7) | (zipcode_data.countInt >=102)]

zipcode_data_derecho_bar.head(10)
# Out:
#       zip       po_name_x        lat        lng  index_right       po_name_y  \
# 0   37013         ANTIOCH  36.049779 -86.650140         51.0         ANTIOCH
# 2   37072  GOODLETTSVILLE  36.307028 -86.725223          8.0  GOODLETTSVILLE
# 3   37076       HERMITAGE  36.187858 -86.605639         46.0       HERMITAGE
# 4   37080         JOELTON  36.343481 -86.884313         20.0         JOELTON
# 6   37122    MOUNT JULIET  36.154386 -86.570678         54.0    MOUNT JULIET
# 8   37189    WHITES CREEK  36.270880 -86.818937         18.0    WHITES CREEK
# 9   37201       NASHVILLE  36.174341 -86.783195         36.0       NASHVILLE
# 18  37211       NASHVILLE  36.068636 -86.725336         49.0       NASHVILLE
# 20  37213       NASHVILLE  36.168109 -86.769268         31.0       NASHVILLE
# 26  37219       NASHVILLE  36.166438 -86.781886         24.0       NASHVILLE
#
#    count                                   LatLong  countInt  \
# 0    191                   [36.247802, -86.716847]       191
# 2      3                   [36.100516, -87.056329]         3
# 3    123                   [36.130021, -86.927819]       123
# 4      4  [36.142379999999996, -86.88188199999999]         4
# 6      1                   [36.047151, -86.962538]         1
# 8      6           [36.093789, -86.83930600000001]         6
# 9      1                   [36.030716, -86.981613]         1
# 18   194           [36.144463, -86.86700400000001]       194
# 20     2                   [36.137391, -86.824951]         2
# 26     3                   [36.025114, -86.961551]         3
#
#                     po_zip
# 0          ANTIOCH - 37013
# 2   GOODLETTSVILLE - 37072
# 3        HERMITAGE - 37076
# 4          JOELTON - 37080
# 6     MOUNT JULIET - 37122
# 8     WHITES CREEK - 37189
# 9        NASHVILLE - 37201
# 18       NASHVILLE - 37211
# 20       NASHVILLE - 37213
# 26       NASHVILLE - 37219

# %%
x = zipcode_data_derecho_bar.sort_values(by='countInt',ascending=True)

ax = x.plot(kind='barh', figsize=(8, 10), x='po_zip', y='countInt',  zorder=2, width=0.85)

totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_width())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.6, i.get_y()+.38, \
            #str(round((i.get_width()/total)*100, 2))+'%', 
             str(round((i.get_width()))),
            fontsize=15,
color='dimgrey')

 # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
 ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("Total Number of Calls", labelpad=20, weight='bold', size=16)

# Set y-axis label
ax.set_ylabel("Location", labelpad=20, weight='bold', size=16)

ax.get_legend().remove()
#ax.legend(loc='lower center', ncol=2, fancybox=True, borderpad=1, frameon=True,  title='Total Calls')
 
ax.set_title("Derecho Calls - Most Impacted, Least Impacted Areas", weight='bold', size=20)
# Out:
# Text(0.5, 1.0, 'Derecho Calls - Most Impacted, Least Impacted Areas')
